# %% [markdown]
# ## 서울시에서 공개한 코로나19 발생동향 분석
# * http://www.seoul.go.kr/coronaV/coronaStatus.do

# %%
# 필요한 라이브러리를 불러옵니다.(판다스로 크롤링이 가능한 사이트가 있다.)

import pandas as pd
import numpy as np

# %%
# 크롤링으로 가져올 url 주소를 입력합니다.

url = 'http://www.seoul.go.kr/coronaV/coronaStatus.do'
url
# Out:
# 'http://www.seoul.go.kr/coronaV/coronaStatus.do'

# %%
# 판다스의 read_html 을 통해 위 url에 있는 불러옵니다.
table = pd.read_html(url)

# %%
# read_html 은 사이트 내의 html 태그를 불러옵니다.

table[0]
# Out:
#    종로구   중구  용산구  성동구  광진구  동대문구  중랑구  성북구  강북구  도봉구  노원구  은평구 서대문구
# 0   29   20   54   57   22    45   44   43   28   64   50   64   41
# 1  마포구  양천구  강서구  구로구  금천구  영등포구  동작구  관악구  서초구  강남구  송파구  강동구   기타
# 2   53   72  106   91   39    72   70  144   64   98   98   49   95

# %%
# table 변수 안에 있는 table 태그의 값을 하나씩 읽어보며 확진자 목록이 있는 테이블을 가져옵니다.

table[6]
# Out:
#         연번     환자    확진일   거주지     여행력         접촉력         조치사항
# 0     1612  14388   8.2.  동대문구       -  타시도 확진자 접촉        서울의료원
# 1     1611  14386   8.2.    대구     이라크    해외 접촉 추정      국립중앙의료원
# 2     1610  14383   8.2.   강서구     필리핀    해외 접촉 추정         서북병원
# 3     1609  14381   8.2.   성북구       -        확인 중        보라매병원
# 4     1608  14382   8.2.   성남시      일본    해외 접촉 추정        서울백병원
# ...    ...    ...    ...   ...     ...         ...          ...
# 1607     5      9  1.31.   성북구       -       #5 접촉    서울의료원(퇴원)
# 1608     4      7  1.30.   마포구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1609     3      6  1.30.   종로구       -       #3 접촉  서울대학교병원(퇴원)
# 1610     2      5  1.30.   중랑구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1611     1      2  1.24.   강서구  중국 우한시       해외 접촉  국립중앙의료원(퇴원)
#
# [1612 rows x 7 columns]

# %%
# 미리보기 합니다.

df = table[6]
df.shape
# Out:
# (1612, 7)

# %%
# 마지막 확진일을 파일명에 써주기 위해 . 을 _ 로 변경합니다.
# 확장자와 구분이 쉽게 되도록 _ 로 변경합니다. 

last_day = df.loc[0, ]
last_day = last_day.replace(".", "_")
last_day
# Out:
# 연번            1612
# 환자           14388
# 확진일           8.2.
# 거주지           동대문구
# 여행력              -
# 접촉력     타시도 확진자 접촉
# 조치사항         서울의료원
# Name: 0, dtype: object

# %%
# 파일명을 만들어 줍니다.
# file_name
#f"" - 문자열을 붙여서 쓸 때 사용

file_name = f"seoul-covid19-{last_day}.csv"
file_name
# Out:
# 'seoul-covid19-연번            1612\n환자           14388\n확진일           8.2.\n거주지           동대문구\n여행력              -\n접촉력     타시도 확진자 접촉\n조치사항         서울의료원\nName: 0, dtype: object.csv'

# %%
# csv 파일로 저장합니다.

df.to_csv(file_name, index = False)

# %%
# 제대로 저장되었는지 확인합니다.

pd.read_csv(file_name)
#unnamed:0이라는 컬럼이 생긴다. -> indexname때문에
#df.to_csv(file_name, index = False)
# Out:
#         연번     환자    확진일   거주지     여행력         접촉력         조치사항
# 0     1612  14388   8.2.  동대문구       -  타시도 확진자 접촉        서울의료원
# 1     1611  14386   8.2.    대구     이라크    해외 접촉 추정      국립중앙의료원
# 2     1610  14383   8.2.   강서구     필리핀    해외 접촉 추정         서북병원
# 3     1609  14381   8.2.   성북구       -        확인 중        보라매병원
# 4     1608  14382   8.2.   성남시      일본    해외 접촉 추정        서울백병원
# ...    ...    ...    ...   ...     ...         ...          ...
# 1607     5      9  1.31.   성북구       -       #5 접촉    서울의료원(퇴원)
# 1608     4      7  1.30.   마포구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1609     3      6  1.30.   종로구       -       #3 접촉  서울대학교병원(퇴원)
# 1610     2      5  1.30.   중랑구  중국 우한시       해외 접촉    서울의료원(퇴원)
# 1611     1      2  1.24.   강서구  중국 우한시       해외 접촉  국립중앙의료원(퇴원)
#
# [1612 rows x 7 columns]
